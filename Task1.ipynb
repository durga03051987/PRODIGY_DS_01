# %% [markdown]
# # Task1:
# # Creating  📊 Barchart for Visulaization of ages and Gender of population

# %% [markdown]
# ## Steps Involved in Task1

# %% [markdown]
#  * For analysis read dataset from worldbank data using pandas library
#  * pandas libarary  used here for converting data set into data frame
#  * Exploratory Data analysis used to seperate numerical variable and Categorical variables
#  * Libraries Matplotlib used for  creating chart and visulaizations

# %% [markdown]
# ## Data set used for this task is downloaded from
# - #### https://data.worldbank.org/indicator/SP.POP.TOTL   &
# - #### CSV file:
# - #### API_SP.POP.TOTL_DS2_en_csv_v2_26346.csv  contains total population data for different countries over the years
# - #### used for data analysis and creating histogram.

# %%
# Import all the necessary packages Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
#Load the main population data  API_SP.POP.TOTL_DS2_en_csv_v2_26346.csv
population_df=pd.read_csv(r"C:\Users\seenu\Desktop\API_SP.POP.TOTL_DS2_en_csv_v2_26346\API_SP.POP.TOTL_DS2_en_csv_v2_26346.csv",skiprows=4) 
population_df
# Out:
#                     Country Name Country Code     Indicator Name  \
# 0                          Aruba          ABW  Population, total
# 1    Africa Eastern and Southern          AFE  Population, total
# 2                    Afghanistan          AFG  Population, total
# 3     Africa Western and Central          AFW  Population, total
# 4                         Angola          AGO  Population, total
# ..                           ...          ...                ...
# 261                       Kosovo          XKX  Population, total
# 262                  Yemen, Rep.          YEM  Population, total
# 263                 South Africa          ZAF  Population, total
# 264                       Zambia          ZMB  Population, total
# 265                     Zimbabwe          ZWE  Population, total
#
#     Indicator Code         1960         1961         1962         1963  \
# 0      SP.POP.TOTL      54922.0      55578.0      56320.0      57002.0
# ...

# %% [markdown]
# ###  It displays  population of each country over the years from 1960 to 2023

# %%
#load the meta data of all countries 
metadata_df=pd.read_csv(r"C:\Users\seenu\Desktop\API_SP.POP.TOTL_DS2_en_csv_v2_26346\Metadata_Country_API_SP.POP.TOTL_DS2_en_csv_v2_26346.csv")
metadata_df
# Out:
#     Country Code                      Region          IncomeGroup  \
# 0            ABW   Latin America & Caribbean          High income
# 1            AFE                         NaN                  NaN
# 2            AFG                  South Asia           Low income
# 3            AFW                         NaN                  NaN
# 4            AGO          Sub-Saharan Africa  Lower middle income
# ..           ...                         ...                  ...
# 260          XKX       Europe & Central Asia  Upper middle income
# 261          YEM  Middle East & North Africa           Low income
# 262          ZAF          Sub-Saharan Africa  Upper middle income
# 263          ZMB          Sub-Saharan Africa  Lower middle income
# 264          ZWE          Sub-Saharan Africa  Lower middle income
#
#                                           SpecialNotes  \
# 0                                                  NaN
# 1    26 countries, stretching from the Red Sea in t...
# ...

# %% [markdown]
# ## It shows countries that related to type of income group

# %%
population_df.head()  #displays top 5 rows
# Out:
#                   Country Name Country Code     Indicator Name Indicator Code  \
# 0                        Aruba          ABW  Population, total    SP.POP.TOTL
# 1  Africa Eastern and Southern          AFE  Population, total    SP.POP.TOTL
# 2                  Afghanistan          AFG  Population, total    SP.POP.TOTL
# 3   Africa Western and Central          AFW  Population, total    SP.POP.TOTL
# 4                       Angola          AGO  Population, total    SP.POP.TOTL
#
#           1960         1961         1962         1963         1964  \
# 0      54922.0      55578.0      56320.0      57002.0      57619.0
# 1  130072080.0  133534923.0  137171659.0  140945536.0  144904094.0
# 2    9035043.0    9214083.0    9404406.0    9604487.0    9814318.0
# 3   97630925.0   99706674.0  101854756.0  104089175.0  106388440.0
# 4    5231654.0    5301583.0    5354310.0    5408320.0    5464187.0
#
#           1965  ...         2015         2016         2017         2018  \
# ...

# %%
metadata_df.head()    #displays top 5 rows
# Out:
#   Country Code                     Region          IncomeGroup  \
# 0          ABW  Latin America & Caribbean          High income
# 1          AFE                        NaN                  NaN
# 2          AFG                 South Asia           Low income
# 3          AFW                        NaN                  NaN
# 4          AGO         Sub-Saharan Africa  Lower middle income
#
#                                         SpecialNotes  \
# 0                                                NaN
# 1  26 countries, stretching from the Red Sea in t...
# 2  The reporting period for national accounts dat...
# 3  22 countries, stretching from the westernmost ...
# 4  The World Bank systematically assesses the app...
#
#                      TableName  Unnamed: 5
# 0                        Aruba         NaN
# 1  Africa Eastern and Southern         NaN
# 2                  Afghanistan         NaN
# 3   Africa Western and Central         NaN
# 4                       Angola         NaN

# %%
population_df.size
# Out:
# 18354

# %%
population_df.shape
# Out:
# (266, 69)

# %%
metadata_df.size
# Out:
# 1590

# %%
metadata_df.shape
# Out:
# (265, 6)

# %%
population_df.columns
# Out:
# Index(['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code',
#        '1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968',
#        '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977',
#        '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986',
#        '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995',
#        '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004',
#        '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
#        '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022',
#        '2023', 'Unnamed: 68'],
#       dtype='object')

# %%
metadata_df.columns
# Out:
# Index(['Country Code', 'Region', 'IncomeGroup', 'SpecialNotes', 'TableName',
#        'Unnamed: 5'],
#       dtype='object')

# %%
population_df.isnull().sum()  #to check the null values it consists of missing valuesin unnamed column
# Out:
# Country Name        0
# Country Code        0
# Indicator Name      0
# Indicator Code      0
# 1960                2
#                  ...
# 2020                1
# 2021                1
# 2022                1
# 2023                1
# Unnamed: 68       266
# Length: 69, dtype: int64

# %%
metadata_df.isnull().sum()    #to check the null values it consists of missing values in unnamed column
# Out:
# Country Code      0
# Region           48
# IncomeGroup      49
# SpecialNotes    138
# TableName         0
# Unnamed: 5      265
# dtype: int64

# %%
#Remove the unused coloumns
pop_clean_df=population_df.drop(columns=['Unnamed: 68'])

# %%
pop_clean_df.head()
# Out:
#                   Country Name Country Code     Indicator Name Indicator Code  \
# 0                        Aruba          ABW  Population, total    SP.POP.TOTL
# 1  Africa Eastern and Southern          AFE  Population, total    SP.POP.TOTL
# 2                  Afghanistan          AFG  Population, total    SP.POP.TOTL
# 3   Africa Western and Central          AFW  Population, total    SP.POP.TOTL
# 4                       Angola          AGO  Population, total    SP.POP.TOTL
#
#           1960         1961         1962         1963         1964  \
# 0      54922.0      55578.0      56320.0      57002.0      57619.0
# 1  130072080.0  133534923.0  137171659.0  140945536.0  144904094.0
# 2    9035043.0    9214083.0    9404406.0    9604487.0    9814318.0
# 3   97630925.0   99706674.0  101854756.0  104089175.0  106388440.0
# 4    5231654.0    5301583.0    5354310.0    5408320.0    5464187.0
#
#           1965  ...         2014         2015         2016         2017  \
# ...

# %% [markdown]
# ### It shows that unused columns are removed

# %%
pop_clean_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 266 entries, 0 to 265
# Data columns (total 68 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Country Name    266 non-null    object
#  1   Country Code    266 non-null    object
#  2   Indicator Name  266 non-null    object
#  3   Indicator Code  266 non-null    object
#  4   1960            264 non-null    float64
#  5   1961            264 non-null    float64
#  6   1962            264 non-null    float64
#  7   1963            264 non-null    float64
#  8   1964            264 non-null    float64
#  9   1965            264 non-null    float64
#  10  1966            264 non-null    float64
#  11  1967            264 non-null    float64
#  12  1968            264 non-null    float64
#  13  1969            264 non-null    float64
#  14  1970            264 non-null    float64
#  15  1971            264 non-null    float64
#  16  1972            264 non-null    float64
# ...

# %% [markdown]
# #### In Population_df  missing values are removed. All columns shows non null values

# %%
meta_clean_df = metadata_df.drop(columns = ['Unnamed: 5'])
meta_clean_df
# Out:
#     Country Code                      Region          IncomeGroup  \
# 0            ABW   Latin America & Caribbean          High income
# 1            AFE                         NaN                  NaN
# 2            AFG                  South Asia           Low income
# 3            AFW                         NaN                  NaN
# 4            AGO          Sub-Saharan Africa  Lower middle income
# ..           ...                         ...                  ...
# 260          XKX       Europe & Central Asia  Upper middle income
# 261          YEM  Middle East & North Africa           Low income
# 262          ZAF          Sub-Saharan Africa  Upper middle income
# 263          ZMB          Sub-Saharan Africa  Lower middle income
# 264          ZWE          Sub-Saharan Africa  Lower middle income
#
#                                           SpecialNotes  \
# 0                                                  NaN
# 1    26 countries, stretching from the Red Sea in t...
# ...

# %%
meta_clean_df.head()  #unused column removed and display first 5 rows
# Out:
#   Country Code                     Region          IncomeGroup  \
# 0          ABW  Latin America & Caribbean          High income
# 1          AFE                        NaN                  NaN
# 2          AFG                 South Asia           Low income
# 3          AFW                        NaN                  NaN
# 4          AGO         Sub-Saharan Africa  Lower middle income
#
#                                         SpecialNotes  \
# 0                                                NaN
# 1  26 countries, stretching from the Red Sea in t...
# 2  The reporting period for national accounts dat...
# 3  22 countries, stretching from the westernmost ...
# 4  The World Bank systematically assesses the app...
#
#                      TableName
# 0                        Aruba
# 1  Africa Eastern and Southern
# 2                  Afghanistan
# 3   Africa Western and Central
# 4                       Angola

# %%
meta_clean_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 265 entries, 0 to 264
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Country Code  265 non-null    object
#  1   Region        217 non-null    object
#  2   IncomeGroup   216 non-null    object
#  3   SpecialNotes  127 non-null    object
#  4   TableName     265 non-null    object
# dtypes: object(5)
# memory usage: 10.5+ KB

# %%
#No missing values im  metadata_df,population_df

# %% [markdown]
# ### ✅   To display Categorical variables of population data

# %%
categorical_columns = pop_clean_df.select_dtypes(include=['object']).columns.tolist(

# Print results
print("Categorical Columns:")
print(categorical_columns)
# Out:
# Categorical Columns:
# ['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code']

# %% [markdown]
# ### 📅To dipalay Numerical variables of Popualation data

# %%
numerical_columns = pop_clean_df.select_dtypes(include=['number']).columns.tolist()
print("Numerical Columns:")
print(numerical_columns)
# Out:
# Numerical Columns:
# ['1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968', '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977', '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986', '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995', '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022', '2023']

# %% [markdown]
# ### ✅   To display Categorical variables of meta data

# %%
categorical_columns = meta_clean_df.select_dtypes(include=['object']).columns.tolist()


print("Categorical Columns:")
print(categorical_columns)
# Out:
# Categorical Columns:
# ['Country Code', 'Region', 'IncomeGroup', 'SpecialNotes', 'TableName']

# %% [markdown]
# ### ✅   To display Numerical variables of meta data

# %%
numerical_columns = meta_clean_df.select_dtypes(include=['number']).columns.tolist()
print("Numerical Columns:")
print(numerical_columns)
# Out:
# Numerical Columns:
# []

# %%
#to display country names from meta data
country_names=meta_clean_df[meta_clean_df['Region'].notna()]['Country Code']
country_names
# Out:
# 0      ABW
# 2      AFG
# 4      AGO
# 5      ALB
# 6      AND
#       ...
# 260    XKX
# 261    YEM
# 262    ZAF
# 263    ZMB
# 264    ZWE
# Name: Country Code, Length: 217, dtype: object

# %%
pop_data=pop_clean_df[pop_clean_df['Country Code'].isin(country_names)]
pop_data     #Population data with out null(missing) values
# Out:
#      Country Name Country Code     Indicator Name Indicator Code        1960  \
# 0           Aruba          ABW  Population, total    SP.POP.TOTL     54922.0
# 2     Afghanistan          AFG  Population, total    SP.POP.TOTL   9035043.0
# 4          Angola          AGO  Population, total    SP.POP.TOTL   5231654.0
# 5         Albania          ALB  Population, total    SP.POP.TOTL   1608800.0
# 6         Andorra          AND  Population, total    SP.POP.TOTL      9510.0
# ..            ...          ...                ...            ...         ...
# 261        Kosovo          XKX  Population, total    SP.POP.TOTL    984846.0
# 262   Yemen, Rep.          YEM  Population, total    SP.POP.TOTL   5532301.0
# 263  South Africa          ZAF  Population, total    SP.POP.TOTL  16440172.0
# 264        Zambia          ZMB  Population, total    SP.POP.TOTL   3153729.0
# 265      Zimbabwe          ZWE  Population, total    SP.POP.TOTL   3809389.0
#
# ...

# %% [markdown]
# ### Distrubution of population in a specific year over categorical variable i.e country names, for categorical variable consider the barchart

# %%
#Here consider the year 2022 for caluculating the population over countries

# %%
df_2022 =pop_data[['Country Name','2022']]

# %%
df_2022
# Out:
#      Country Name        2022
# 0           Aruba    107310.0
# 2     Afghanistan  40578842.0
# 4          Angola  35635029.0
# 5         Albania   2777689.0
# 6         Andorra     79705.0
# ..            ...         ...
# 261        Kosovo   1768096.0
# 262   Yemen, Rep.  38222876.0
# 263  South Africa  62378410.0
# 264        Zambia  20152938.0
# 265      Zimbabwe  16069056.0
#
# [217 rows x 2 columns]

# %%
# Consider the distibution of population for top 10 countries

# %%
top10=df_2022.sort_values('2022',ascending=False).head(10)
top10
# Out:
#            Country Name          2022
# 109               India  1.425423e+09
# 40                China  1.412175e+09
# 251       United States  3.332714e+08
# 106           Indonesia  2.788305e+08
# 184            Pakistan  2.437007e+08
# 174             Nigeria  2.231509e+08
# 29               Brazil  2.103064e+08
# 20           Bangladesh  1.693849e+08
# 202  Russian Federation  1.442369e+08
# 154              Mexico  1.286131e+08

# %%
# Distribution of population for top 10 countries with categorical variable Country Name

# %% [markdown]
# ### Let us  consider  📊 Bar Chart for population of top 10 countries in 2022

# %%
plt.figure(figsize=(12,6))
plt.bar(top10['Country Name'],top10['2022'],color='green')
plt.xticks(rotation=45)
plt.xlabel("Country Names")
plt.ylabel("Population in Billions")
plt.title("TOP 10 Most populous countries in 2022")
plt.show()

# %%
## Summary  :  TOP 10 Most populous Countries  in 2022

# %% [markdown]
# ## 📊 Top 10 Most Populous Countries in 2022 – Summary
#
# - **India and China are the most populous countries**, each with populations exceeding 1 billion, closely competing for the top spot.
#
# - The United States ranks third, but its population is significantly lower than India and China—less than half a billion.
#
# - Indonesia and Pakistan follow, reflecting strong population growth in Southeast and South Asia.
#
# - Nigeria is the most populous country in Africa, highlighting rapid population growth on the continent.
#
# - Brazil, Bangladesh, and Russia also make the list, each with populations above 100 million.
#
# - Mexico rounds out the top 10, indicating its demographic weight in Latin America.
#
# - There's a steep drop-off in population size after the top 2 (India and China), with the rest gradually decreasing.
#
# - Asia dominates the chart, with 6 out of 10 countries coming from the continent.
#
# - The chart suggests a shift in global population centers toward developing countries, especially in Africa and South Asia.
#
# - The color green emphasizes population size positively, often associated with growth or prosperity.

# %%
## In the same way Consider the distubution of population of 10 countries  over 2023

# %%
df_2023 =pop_data[['Country Name','2023']]

# %%
df_2023
# Out:
#      Country Name        2023
# 0           Aruba    107359.0
# 2     Afghanistan  41454761.0
# 4          Angola  36749906.0
# 5         Albania   2745972.0
# 6         Andorra     80856.0
# ..            ...         ...
# 261        Kosovo   1756366.0
# 262   Yemen, Rep.  39390799.0
# 263  South Africa  63212384.0
# 264        Zambia  20723965.0
# 265      Zimbabwe  16340822.0
#
# [217 rows x 2 columns]

# %%
top10_23=df_2023.sort_values('2023',ascending=False).head(10)
top10_23
# Out:
#            Country Name          2023
# 109               India  1.438070e+09
# 40                China  1.410710e+09
# 251       United States  3.349149e+08
# 106           Indonesia  2.811901e+08
# 184            Pakistan  2.475045e+08
# 174             Nigeria  2.278829e+08
# 29               Brazil  2.111407e+08
# 20           Bangladesh  1.714670e+08
# 202  Russian Federation  1.438261e+08
# 154              Mexico  1.297398e+08

# %% [markdown]
#  ### 📊 Bar Chart for population of top 10 countries in 2023

# %%
plt.figure(figsize=(10,5))
plt.bar(top10['Country Name'],top10_23['2023'],color='orange')
plt.xticks(rotation=45)
plt.xlabel("Country Names")
plt.ylabel("Population in Billions")
plt.title("TOP 10 Most populous countries in 2023")
plt.show()

# %% [markdown]
# ##   Summary  - Top 10 Most Populous Countries in 2023

# %% [markdown]
# - **India is the most populous country**with approximately 1.44 billion people, surpassing China.
#
# - China is in second place, just slightly behind India, with about 1.41 billion people.
#
# - United States ranks third with a population of around 335 million, significantly lower than the top two.
#
# - **No European Countries appearing the top 10**.ndicatig lowgrowth or aging populations in Europe.
#
# - Indonesia ,Pakistan,Brazil,Nigeria,Bagngladesh, Russia and Mexicoround out the TOP10.
#
# - **Nigeria standsout with rapid growth** and becomeone of top3 in coming decades.
#
# -  There is huge gap between top two  India and China and rest higlighting global population imbalance
#
# -  Most countries in the list have young,growing population,offering growth potential
#
# -  The list is dominated byA sian countries showing demograohic significace
